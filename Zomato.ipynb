# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projects/zomato_analytics_dataset.csv')

# %%
df.head()
# Out:
#    Order_ID Customer_ID           Restaurant_Name       City  Cuisine_Type  \
# 0  ORD00001    CUST5824  Becker, Dorsey and Nunez  Bangalore       Chinese
# 1  ORD00002    CUST8654                Kim-Hunter    Kolkata   Continental
# 2  ORD00003    CUST1015                Powell Inc      Delhi       Chinese
# 3  ORD00004    CUST5784            West-Schneider    Kolkata          Thai
# 4  ORD00005    CUST5540                 Patel LLC    Chennai  South Indian
#
#   Dish_Name  Order_Date Order_Time Order_Status  Delivery_Duration_Minutes  \
# 0    Nature  18-09-2024   18:46:00    Delivered                       87.0
# 1  Evidence  02-07-2024   18:01:41    Delivered                       61.0
# 2     Among  21-05-2024   12:02:54    Cancelled                        NaN
# 3        He  31-01-2025   02:59:17    Delivered                       25.0
# 4      Year  02-11-2024   22:32:50    Delivered                       68.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order_ID                   10000 non-null  object
#  1   Customer_ID                10000 non-null  object
#  2   Restaurant_Name            10000 non-null  object
#  3   City                       10000 non-null  object
#  4   Cuisine_Type               10000 non-null  object
#  5   Dish_Name                  9993 non-null   object
#  6   Order_Date                 10000 non-null  object
#  7   Order_Time                 10000 non-null  object
#  8   Order_Status               10000 non-null  object
#  9   Delivery_Duration_Minutes  7964 non-null   float64
#  10  Payment_Method             10000 non-null  object
#  11  Order_Value                10000 non-null  float64
#  12  Discount_Applied           10000 non-null  object
# ...

# %%
df.describe()
# Out:
#        Delivery_Duration_Minutes   Order_Value  Customer_Rating  \
# count                7964.000000  10000.000000      3947.000000
# mean                   55.036288    551.122908         2.986572
# std                    20.328776    261.115222         1.152453
# min                    20.000000    100.050000         1.000000
# 25%                    37.000000    325.330000         2.000000
# 50%                    55.000000    551.585000         3.000000
# 75%                    73.000000    779.940000         4.000000
# max                    90.000000    999.990000         5.000000
#
#        Delivery_Partner_Rating  Restaurant_Rating    Tip_Amount
# count              3938.000000       10000.000000  10000.000000
# mean                  2.977476           4.009810     40.126607
# std                   1.165457           0.580483     32.667671
# min                   1.000000           3.000000      0.000000
# 25%                   2.000000           3.500000      6.237500
# ...

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Customer_ID                     0
# Restaurant_Name                 0
# City                            0
# Cuisine_Type                    0
# Dish_Name                       7
# Order_Date                      0
# Order_Time                      0
# Order_Status                    0
# Delivery_Duration_Minutes    2036
# Payment_Method                  0
# Order_Value                     0
# Discount_Applied                0
# Customer_Rating              6053
# Delivery_Partner_ID             0
# Delivery_Partner_Rating      6062
# Cancellation_Reason          8371
# Is_First_Order                  0
# Restaurant_Rating               0
# Tip_Amount                      0
# dtype: int64

# %%
df['Delivery_Duration_Minutes'].value_counts()
# Out:
# Delivery_Duration_Minutes
# 32.0    143
# 35.0    134
# 76.0    133
# 58.0    131
# 61.0    130
#        ...
# 87.0     96
# 71.0     94
# 38.0     93
# 56.0     91
# 45.0     89
# Name: count, Length: 71, dtype: int64

# %%
df['Delivery_Duration_Minutes'].mean()
# Out:
# np.float64(55.03628829733802)

# %%
df['Delivery_Duration_Minutes'].fillna(df['Delivery_Duration_Minutes'].mean(), inplace=True)
# Out:
# <ipython-input-87-27105695a42c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Delivery_Duration_Minutes'].fillna(df['Delivery_Duration_Minutes'].mean(), inplace=True)

# %%
df['Delivery_Duration_Minutes'].mean()
# Out:
# np.float64(55.036288297338025)

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Customer_ID                     0
# Restaurant_Name                 0
# City                            0
# Cuisine_Type                    0
# Dish_Name                       7
# Order_Date                      0
# Order_Time                      0
# Order_Status                    0
# Delivery_Duration_Minutes       0
# Payment_Method                  0
# Order_Value                     0
# Discount_Applied                0
# Customer_Rating              6053
# Delivery_Partner_ID             0
# Delivery_Partner_Rating      6062
# Cancellation_Reason          8371
# Is_First_Order                  0
# Restaurant_Rating               0
# Tip_Amount                      0
# dtype: int64

# %%
df['Cancellation_Reason'].fillna('Not Cancelled', inplace=True)
# Out:
# <ipython-input-90-52ad2fcdea9c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cancellation_Reason'].fillna('Not Cancelled', inplace=True)

# %%
df['Cancellation_Reason'].value_counts()
# Out:
# Cancellation_Reason
# Not Cancelled               8371
# Delivery Partner No Show     420
# Restaurant Unavailable       418
# Customer Cancelled           403
# Other                        388
# Name: count, dtype: int64

# %%
df['Customer_Rating'].mean()
# Out:
# np.float64(2.9865720800608053)

# %%
df['Customer_Rating'].fillna(df['Customer_Rating'].mean(), inplace=True)
# Out:
# <ipython-input-93-005ba09dc10a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Customer_Rating'].fillna(df['Customer_Rating'].mean(), inplace=True)

# %%
df['Customer_Rating'].mean()
# Out:
# np.float64(2.9865720800608053)

# %%
df['Customer_Rating']
# Out:
# 0       3.100000
# 1       2.986572
# 2       2.986572
# 3       2.986572
# 4       4.200000
#           ...
# 9995    2.986572
# 9996    2.900000
# 9997    2.986572
# 9998    2.986572
# 9999    4.400000
# Name: Customer_Rating, Length: 10000, dtype: float64

# %%
df.describe()
# Out:
#        Delivery_Duration_Minutes   Order_Value  Customer_Rating  \
# count               10000.000000  10000.000000     10000.000000
# mean                   55.036288    551.122908         2.986572
# std                    18.141421    261.115222         0.723975
# min                    20.000000    100.050000         1.000000
# 25%                    42.000000    325.330000         2.986572
# 50%                    55.036288    551.585000         2.986572
# 75%                    68.000000    779.940000         2.986572
# max                    90.000000    999.990000         5.000000
#
#        Delivery_Partner_Rating  Restaurant_Rating    Tip_Amount
# count              3938.000000       10000.000000  10000.000000
# mean                  2.977476           4.009810     40.126607
# std                   1.165457           0.580483     32.667671
# min                   1.000000           3.000000      0.000000
# 25%                   2.000000           3.500000      6.237500
# ...

# %%
df.head()
# Out:
#    Order_ID Customer_ID           Restaurant_Name       City  Cuisine_Type  \
# 0  ORD00001    CUST5824  Becker, Dorsey and Nunez  Bangalore       Chinese
# 1  ORD00002    CUST8654                Kim-Hunter    Kolkata   Continental
# 2  ORD00003    CUST1015                Powell Inc      Delhi       Chinese
# 3  ORD00004    CUST5784            West-Schneider    Kolkata          Thai
# 4  ORD00005    CUST5540                 Patel LLC    Chennai  South Indian
#
#   Dish_Name  Order_Date Order_Time Order_Status  Delivery_Duration_Minutes  \
# 0    Nature  18-09-2024   18:46:00    Delivered                  87.000000
# 1  Evidence  02-07-2024   18:01:41    Delivered                  61.000000
# 2     Among  21-05-2024   12:02:54    Cancelled                  55.036288
# 3        He  31-01-2025   02:59:17    Delivered                  25.000000
# 4      Year  02-11-2024   22:32:50    Delivered                  68.000000
#
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
# Out:
# <ipython-input-98-422bc60de3cd>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order_ID                   10000 non-null  object
#  1   Customer_ID                10000 non-null  object
#  2   Restaurant_Name            10000 non-null  object
#  3   City                       10000 non-null  object
#  4   Cuisine_Type               10000 non-null  object
#  5   Dish_Name                  9993 non-null   object
#  6   Order_Date                 10000 non-null  datetime64[ns]
#  7   Order_Time                 10000 non-null  object
#  8   Order_Status               10000 non-null  object
#  9   Delivery_Duration_Minutes  10000 non-null  float64
#  10  Payment_Method             10000 non-null  object
#  11  Order_Value                10000 non-null  float64
#  12  Discount_Applied           10000 non-null  object
# ...

# %%
df.head(10)
# Out:
#    Order_ID Customer_ID             Restaurant_Name       City  Cuisine_Type  \
# 0  ORD00001    CUST5824    Becker, Dorsey and Nunez  Bangalore       Chinese
# 1  ORD00002    CUST8654                  Kim-Hunter    Kolkata   Continental
# 2  ORD00003    CUST1015                  Powell Inc      Delhi       Chinese
# 3  ORD00004    CUST5784              West-Schneider    Kolkata          Thai
# 4  ORD00005    CUST5540                   Patel LLC    Chennai  South Indian
# 5  ORD00006    CUST7944                 Norman-Sims  Hyderabad       Italian
# 6  ORD00007    CUST4713              Lopez and Sons       Pune          Thai
# 7  ORD00008    CUST3423                 Goodwin LLC  Bangalore          Thai
# 8  ORD00009    CUST1235              Thompson Group    Chennai   Continental
# 9  ORD00010    CUST8019  Landry, Castillo and Myers  Bangalore       Italian
#
#    Dish_Name Order_Date Order_Time Order_Status  Delivery_Duration_Minutes  \
# ...

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Customer_ID                     0
# Restaurant_Name                 0
# City                            0
# Cuisine_Type                    0
# Dish_Name                       7
# Order_Date                      0
# Order_Time                      0
# Order_Status                    0
# Delivery_Duration_Minutes       0
# Payment_Method                  0
# Order_Value                     0
# Discount_Applied                0
# Customer_Rating                 0
# Delivery_Partner_ID             0
# Delivery_Partner_Rating      6062
# Cancellation_Reason             0
# Is_First_Order                  0
# Restaurant_Rating               0
# Tip_Amount                      0
# dtype: int64

# %%
df.dropna(subset=['Dish_Name'], inplace=True)

# %%
df.shape
# Out:
# (9993, 20)

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Customer_ID                     0
# Restaurant_Name                 0
# City                            0
# Cuisine_Type                    0
# Dish_Name                       0
# Order_Date                      0
# Order_Time                      0
# Order_Status                    0
# Delivery_Duration_Minutes       0
# Payment_Method                  0
# Order_Value                     0
# Discount_Applied                0
# Customer_Rating                 0
# Delivery_Partner_ID             0
# Delivery_Partner_Rating      6056
# Cancellation_Reason             0
# Is_First_Order                  0
# Restaurant_Rating               0
# Tip_Amount                      0
# dtype: int64

# %%
df
# Out:
#       Order_ID Customer_ID               Restaurant_Name       City  \
# 0     ORD00001    CUST5824      Becker, Dorsey and Nunez  Bangalore
# 1     ORD00002    CUST8654                    Kim-Hunter    Kolkata
# 2     ORD00003    CUST1015                    Powell Inc      Delhi
# 3     ORD00004    CUST5784                West-Schneider    Kolkata
# 4     ORD00005    CUST5540                     Patel LLC    Chennai
# ...        ...         ...                           ...        ...
# 9995  ORD09996    CUST4855                Schwartz-Velez    Chennai
# 9996  ORD09997    CUST3874  Paul, Johnson and Richardson       Pune
# 9997  ORD09998    CUST7928                 Jackson-Frank  Bangalore
# 9998  ORD09999    CUST4131                     Smith Ltd    Kolkata
# 9999  ORD10000    CUST3804                    Downs-Hull      Delhi
#
#       Cuisine_Type Dish_Name Order_Date Order_Time Order_Status  \
# 0          Chinese    Nature 2024-09-18   18:46:00    Delivered
# ...

# %%
df.to_csv('Cleaned.csv', index=False)

# %%
clean = pd.read_csv('/content/Cleaned.csv')

# %%
clean
# Out:
#       Order_ID Customer_ID               Restaurant_Name       City  \
# 0     ORD00001    CUST5824      Becker, Dorsey and Nunez  Bangalore
# 1     ORD00002    CUST8654                    Kim-Hunter    Kolkata
# 2     ORD00003    CUST1015                    Powell Inc      Delhi
# 3     ORD00004    CUST5784                West-Schneider    Kolkata
# 4     ORD00005    CUST5540                     Patel LLC    Chennai
# ...        ...         ...                           ...        ...
# 9988  ORD09996    CUST4855                Schwartz-Velez    Chennai
# 9989  ORD09997    CUST3874  Paul, Johnson and Richardson       Pune
# 9990  ORD09998    CUST7928                 Jackson-Frank  Bangalore
# 9991  ORD09999    CUST4131                     Smith Ltd    Kolkata
# 9992  ORD10000    CUST3804                    Downs-Hull      Delhi
#
#       Cuisine_Type Dish_Name  Order_Date Order_Time Order_Status  \
# 0          Chinese    Nature  2024-09-18   18:46:00    Delivered
# ...
